# %%
import numpy as np
import pandas as pd

# %%
#1. Otener información del archivo udfs.csv
read_UDFS_csv = pd.read_csv('udfs.csv', sep=';')
read_UDFS_csv
filter_dfFusuion = read_UDFS_csv.loc[:,'string_value'] != 1999
filter_FXSwaps = read_UDFS_csv.loc[filter_dfFusuion]
filter_FXSwaps
# Out:
#            nb  contract   udf_ref fmly    grp type country      udf_name  \
# 0      444444      3333  28786653  IRD  LN_BR  NaN     ESP         M_CCY
# 1     2222222   2222222   2222222  IRD    IRS  NaN     ESP    M_CRDTCHRG
# 2     2222222   2222222   2222222  IRD    IRS  NaN     ESP      M_SELLER
# 3     2222222   2222222   2222222  IRD    IRS  NaN     ESP  M_LIQDTYCHRG
# 4     2222222   2222222   2222222  IRD    IRS  NaN     ESP         M_MVA
# ..        ...       ...       ...  ...    ...  ...     ...           ...
# 381  10000009  10000009  10000009  IRD   BOND  FWD     ESP    M_SUCURSAL
# 382  10000009  10000009  10000009  IRD   BOND  FWD     ESP         M_RVA
# 383  10000009  10000009  10000009  IRD   BOND  FWD     ESP   M_DIRECTIAV
# 384  10000009  10000009  10000009  IRD   BOND  FWD     ESP      M_CLIENT
# 385  10000009  10000009  10000009  IRD   BOND  FWD     ESP  M_DISCMARGIN
#
#      num_value string_value  date_value  data_timestamp_part data_date_part  \
# ...

# %%
df_udfs = pd.DataFrame(data=read_UDFS_csv, columns=['nb', 'M_CCY', 'M_CLIENT', 'M_CRDTCHRG', 'M_DIRECTIAV', 'M_DISCMARGIN', 'M_LIQDTYCHRG', 'M_MVA', 'M_RVA', 'M_SELLER', 'M_SUCURSAL'])
df_udfs
# df2 = df1.replace({'col1':{'value1':'new_value1','value2':'new_value2'}})

# df_udfs1 = read_UDFS_csv.copy({'udf_name':{'M_CLIENT':'string_value', 'M_SELLER':'string_value'}})
# # df_udfs
# # df_udfs.to_excel('prueba datos.xlsx')
# print(df_udfs1)

print(read_UDFS_csv['udf_name'][read_UDFS_csv['num_value'] == 'M-CLIENT'].dropna())
# Out:
# Series([], Name: udf_name, dtype: object)
#            nb  contract   udf_ref fmly    grp type country      udf_name  \
# 0      444444      3333  28786653  IRD  LN_BR  NaN     ESP         M_CCY
# 1     2222222   2222222   2222222  IRD    IRS  NaN     ESP    M_CRDTCHRG
# 2     2222222   2222222   2222222  IRD    IRS  NaN     ESP      M_SELLER
# 3     2222222   2222222   2222222  IRD    IRS  NaN     ESP  M_LIQDTYCHRG
# 4     2222222   2222222   2222222  IRD    IRS  NaN     ESP         M_MVA
# ..        ...       ...       ...  ...    ...  ...     ...           ...
# 381  10000009  10000009  10000009  IRD   BOND  FWD     ESP    M_SUCURSAL
# 382  10000009  10000009  10000009  IRD   BOND  FWD     ESP         M_RVA
# 383  10000009  10000009  10000009  IRD   BOND  FWD     ESP   M_DIRECTIAV
# 384  10000009  10000009  10000009  IRD   BOND  FWD     ESP      M_CLIENT
# 385  10000009  10000009  10000009  IRD   BOND  FWD     ESP  M_DISCMARGIN
#
# ...
